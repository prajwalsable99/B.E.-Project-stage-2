# %%
import pandas as pd

# %%
df=pd.read_csv('wheat overall.csv')

# %%
df.head()
# Out:
#    Dist Code  Year  State Code    State Name Dist Name  WHEAT AREA (1000 ha)  \
# 0          1  2008          14  Chhattisgarh      Durg                 36.46
# 1          1  2009          14  Chhattisgarh      Durg                 42.44
# 2          1  2010          14  Chhattisgarh      Durg                 46.12
# 3          1  2011          14  Chhattisgarh      Durg                 44.98
# 4          1  2012          14  Chhattisgarh      Durg                 43.87
#
#    WHEAT PRODUCTION (1000 tons)  WHEAT YIELD (Kg per ha)
# 0                         31.19                   855.47
# 1                         38.12                   898.09
# 2                         45.87                   994.69
# 3                         50.19                  1115.68
# 4                         47.69                  1087.10

# %%
new_df= df.drop(['Dist Name','State Name'],axis=1)

# %%
X= new_df.iloc[: , 0:3 ]
Y=new_df.iloc[ : ,5:6]

# %%
X
# Out:
#       Dist Code  Year  State Code
# 0             1  2008          14
# 1             1  2009          14
# 2             1  2010          14
# 3             1  2011          14
# 4             1  2012          14
# ...         ...   ...         ...
# 3101        917  2013          15
# 3102        917  2014          15
# 3103        917  2015          15
# 3104        917  2016          15
# 3105        917  2017          15
#
# [3106 rows x 3 columns]

# %%
Y
# Out:
#       WHEAT YIELD (Kg per ha)
# 0                      855.47
# 1                      898.09
# 2                      994.69
# 3                     1115.68
# 4                     1087.10
# ...                       ...
# 3101                  1209.15
# 3102                  1240.67
# 3103                   914.57
# 3104                  2167.98
# 3105                     0.00
#
# [3106 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor()
regressor.fit(X_train, y_train)
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_25528/3410425847.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(X_train, y_train)
# RandomForestRegressor()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred=regressor.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8990406837344944

# %%
import math
math.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 422.5542243670279

# %%
df.loc[df['Dist Name'] == 'Pune'].sort_values('Year', ascending=True)
# Out:
#       Dist Code  Year  State Code   State Name Dist Name  \
# 1016        103  2008           7  Maharashtra      Pune
# 1017        103  2009           7  Maharashtra      Pune
# 1018        103  2010           7  Maharashtra      Pune
# 1019        103  2011           7  Maharashtra      Pune
# 1020        103  2012           7  Maharashtra      Pune
# 1021        103  2013           7  Maharashtra      Pune
# 1022        103  2014           7  Maharashtra      Pune
# 1023        103  2015           7  Maharashtra      Pune
# 1024        103  2016           7  Maharashtra      Pune
# 1025        103  2017           7  Maharashtra      Pune
#
#       WHEAT AREA (1000 ha)  WHEAT PRODUCTION (1000 tons)  \
# 1016                  60.9                        112.30
# 1017                  59.6                         91.81
# 1018                  60.0                        115.93
# 1019                  55.3                        105.56
# 1020                  53.0                         93.82
# 1021                  64.3                        129.90
# 1022                  71.8                        108.30
# 1023                  62.0                        129.60
# 1024                  68.9                        165.20
# 1025                  72.4                        177.20
#
#       WHEAT YIELD (Kg per ha)
# 1016                  1844.01
# 1017                  1540.44
# 1018                  1932.17
# 1019                  1908.86
# 1020                  1770.19
# 1021                  2020.22
# 1022                  1508.36
# 1023                  2090.32
# 1024                  2397.68
# 1025                  2447.51

# %%
# creating inputs

# %%
fil=df[ ['State Name','State Code','Dist Name','Dist Code' ]].drop_duplicates().sort_values(['State Name', 'Dist Name' ], ascending=True)

# %%
grouped = fil.groupby('State Name')
result = []
for state, group in grouped:
    state_dict = {'State Name': state, 'State Code': group.iloc[0]['State Code'], 'Districts': group[['Dist Name', 'Dist Code']].to_dict('records')}
    result.append(state_dict)

# convert the list of dictionaries to a JSON string
json_str = pd.io.json.dumps(result)

# print(json_str)

# %%
import json



# parse the JSON string to a Python object
data = json.loads(json_str)

# write the Python object to a JSON file
with open('inputdatatop5.json', 'w') as f:
    json.dump(data, f)
